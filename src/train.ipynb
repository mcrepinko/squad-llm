# %%
# %load_ext tensorboard
# %tensorboard --logdir '../model/t5_abs_qa/runs'
# Out:
# Launching TensorBoard...

# %%
# !python train.py
# Out:
# ...
# Map (num_proc=3): 100%|████████████| 1000/1000 [00:00<00:00, 1412.83 examples/s]
# /home/m31/Documents/code_base/projects/squad-llm/src/train.py:91: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#
# -------- PRINT CONFIG --------
# DATA={'dataset_name': 'rajpurkar/squad', 'dataset_path': '../data/squad', 'train_file_path': 'train/data-00000-of-00001.arrow', 'test_file_path': 'test/data-00000-of-00001.arrow', 'validation_file_path': 'validation/data-00000-of-00001.arrow', 'test_size': 0.12, 'remove_columns': ['id', 'title', 'answers']}
# MODEL={'use_gpu': True, 'model_name': 'google-t5/t5-small', 'model_path': '../model', 'model_cache_path': '../model/cache', 'hyperparams': {'max_inpt_len': 256, 'max_label_len': 32}, 'generation_config': {'num_beams': 4, 'early_stopping': True, 'top_k': 50, 'top_p': 0.92, 'do_sample': True, 'repetition_penalty': 1.2}}
# ...

# %% [markdown]
# ## **Evaluation on a validation set before and after FT**

# %% [raw]
# -------- EVALUATION BEFORE TRAINING --------
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# 100%|█████████████████████████████████████████| 500/500 [05:17<00:00,  1.58it/s]
# {'eval_loss': 24.801977157592773, 'eval_model_preparation_time': 0.0026, 'eval_rouge1': 61.848463041019855, 'eval_rouge2': 42.22107969151671, 'eval_rougeL': 52.698673794592374, 'eval_rougeLsum': 61.66341112367637, 'eval_runtime': 318.1294, 'eval_samples_per_second': 3.143, 'eval_steps_per_second': 1.572}
#
#
#
# -------- EVALUATION AFTER TRAINING --------
# 100%|█████████████████████████████████████████| 500/500 [04:59<00:00,  1.67it/s]
# {'eval_loss': 0.15876847505569458, 'eval_model_preparation_time': 0.0026, 'eval_rouge1': 76.1731207289294, 'eval_rouge2': 50.28102688743734, 'eval_rougeL': 61.92862566438877, 'eval_rougeLsum': 75.99088838268793, 'eval_runtime': 300.2597, 'eval_samples_per_second': 3.33, 'eval_steps_per_second': 1.665, 'epoch': 6.0}

# %%
from IPython.display import Image
Image(filename='assets/tb_graphs.png')
